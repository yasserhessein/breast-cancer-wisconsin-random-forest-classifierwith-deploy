# %% [markdown]
# ## **Datsset Breast Cancer Wisconsin**
#
#
#
#
# ### https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Original%29
#
#
#
#
#
# ![](https://www.itnonline.com/sites/default/files/styles/content_large/public/Mammography_A%20spot%20magnification%20view%20demonstrates%20an%20irregular%20spiculated%20mass%20with%20associated%20calcifications%20in%20the%20upper%20outer%20left%20breast_From%20RSNA%202014%20release.jpg?itok=iw3PSYO6)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../input/breast-cancer-wisconsin/Breast Cancer Prediction.csv')

# %%
df.head()
# Out:
#    Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0             1000025                5                        1
# 1             1002945                5                        4
# 2             1015425                3                        1
# 3             1016277                6                        8
# 4             1017023                4                        1
#
#    Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                         1                  1                            2
# 1                         4                  5                            7
# 2                         1                  1                            2
# 3                         8                  1                            3
# 4                         1                  3                            2
#
#    Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sample code number           683 non-null    int64
#  1   Clump Thickness              683 non-null    int64
#  2   Uniformity of Cell Size      683 non-null    int64
#  3   Uniformity of Cell Shape     683 non-null    int64
#  4   Marginal Adhesion            683 non-null    int64
#  5   Single Epithelial Cell Size  683 non-null    int64
#  6   Bare Nuclei                  683 non-null    int64
#  7   Bland Chromatin              683 non-null    int64
#  8   Normal Nucleoli              683 non-null    int64
#  9   Mitoses                      683 non-null    int64
#  10  Class                        683 non-null    int64
# dtypes: int64(11)
# memory usage: 58.8 KB

# %%
df.describe()
# Out:
#        Sample code number  Clump Thickness  Uniformity of Cell Size  \
# count        6.830000e+02       683.000000               683.000000
# mean         1.076720e+06         4.442167                 3.150805
# std          6.206440e+05         2.820761                 3.065145
# min          6.337500e+04         1.000000                 1.000000
# 25%          8.776170e+05         2.000000                 1.000000
# 50%          1.171795e+06         4.000000                 1.000000
# 75%          1.238705e+06         6.000000                 5.000000
# max          1.345435e+07        10.000000                10.000000
#
#        Uniformity of Cell Shape  Marginal Adhesion  \
# count                683.000000         683.000000
# mean                   3.215227           2.830161
# std                    2.988581           2.864562
# min                    1.000000           1.000000
# 25%                    1.000000           1.000000
# ...

# %%
df.isnull().sum()
# Out:
# Sample code number             0
# Clump Thickness                0
# Uniformity of Cell Size        0
# Uniformity of Cell Shape       0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Bland Chromatin                0
# Normal Nucleoli                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %%
df.corr()
# Out:
#                              Sample code number  Clump Thickness  \
# Sample code number                     1.000000        -0.056350
# Clump Thickness                       -0.056350         1.000000
# Uniformity of Cell Size               -0.041396         0.642481
# Uniformity of Cell Shape              -0.042221         0.653470
# Marginal Adhesion                     -0.069630         0.487829
# Single Epithelial Cell Size           -0.048644         0.523596
# Bare Nuclei                           -0.099248         0.593091
# Bland Chromatin                       -0.061966         0.553742
# Normal Nucleoli                       -0.050699         0.534066
# Mitoses                               -0.037972         0.350957
# Class                                 -0.084701         0.714790
#
#                              Uniformity of Cell Size  \
# Sample code number                         -0.041396
# Clump Thickness                             0.642481
# ...

# %%
sns.countplot(df['Class'],label="Count")

# %%
df
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1000025                5                        1
# 1               1002945                5                        4
# 2               1015425                3                        1
# 3               1016277                6                        8
# 4               1017023                4                        1
# ..                  ...              ...                      ...
# 678              776715                3                        1
# 679              841769                2                        1
# 680              888820                5                       10
# 681              897471                4                        8
# 682              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           1                  1                            2
# ...

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True, fmt='.0%')

# %%
X = df.iloc[:, 0:9].values 
Y = df.iloc[:, 10].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
  from sklearn.ensemble import RandomForestClassifier
  forest = RandomForestClassifier(n_estimators = 25, criterion = 'entropy', random_state = 10)
  forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=25, random_state=10)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = forest.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[84  3]
#  [ 1 49]]
# 0.9708029197080292

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = forest, X = X_train, y = y_train, cv = 10)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy: 97.06 %
# Standard Deviation: 2.36 %

# %%
int(round(forest.predict([[4,5,5,7,1,6,4,5,1]])[0]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-76b6f999278e> in <module>
# ----> 1 int(round(forest.predict([[4,5,5,7,1,6,4,5,1]])[1]))
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
import joblib

# %%
joblib.dump(forest, 'model2.pkl')
